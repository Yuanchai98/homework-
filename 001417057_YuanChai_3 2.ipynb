# %%
class ProbDist(dict):
    """A Probability Distribution; an {outcome: probability} mapping."""
    def __init__(self, mapping=(), **kwargs):
        self.update(mapping, **kwargs)
        # Make probabilities sum to 1.0; assert no negative probabilities
        total = sum(self.values())
        for outcome in self:
            self[outcome] = self[outcome] / total
            assert self[outcome] >= 0

# %%
def p(event, space): 
    """The probability of an event, given a sample space of outcomes. 
    event: a collection of outcomes, or a predicate that is true of outcomes in the event. 
    space: a set of outcomes or a probability distribution of {outcome: frequency} pairs."""
    
    # if event is a predicate it, "unroll" it as a collection 
    if is_predicate(event):
        event = such_that(event, space)
        
    # if space is not an equiprobably collection (a simple set), 
    # but a probability distribution instead (a dictionary set),
    # then add (union) the probabilities for all favorable outcomes
    if isinstance(space, ProbDist):
        return sum(space[o] for o in space if o in event)
    
    # simplest case: what we played with in our previous lesson
    else:
        return Fraction(len(event & space), len(space))

is_predicate = callable

# Here we either return a simple collection in the case of equiprobable outcomes, or a dictionary collection in the
# case of non-equiprobably outcomes
def such_that(predicate, space): 
    """The outcomes in the sample pace for which the predicate is true.
    If space is a set, return a subset {outcome,...} with outcomes where predicate(element) is true;
    if space is a ProbDist, return a ProbDist {outcome: frequency,...} with outcomes where predicate(element) is true."""
    if isinstance(space, ProbDist):
        return ProbDist({o:space[o] for o in space if predicate(o)})
    else:
        return {o for o in space if predicate(o)}

# %%
def joint(A, B, sep=''):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b: A[a] * B[b]
                    for a in A
                    for b in B})

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### what is the Probability Distribution for each F1 driver to win the Singaporean Grand Prix?

# %%
SGP = ProbDist(
    LH = 296, VB = 231, CL = 200, MV = 200, SV = 194, PG = 69, CS = 58, AA = 42, DR = 34, DK = 33,
    NH = 33, LN = 31, KR = 31, SP = 27, LS = 19, KM = 18, RG = 8, AG = 4, RK = 1, GR = 0,
    )


SGP
# Out:
# {'LH': 0.1935905820797907,
#  'VB': 0.1510791366906475,
#  'CL': 0.13080444735120994,
#  'MV': 0.13080444735120994,
#  'SV': 0.12688031393067364,
#  'PG': 0.04512753433616743,
#  'CS': 0.03793328973185088,
#  'AA': 0.027468933943754086,
#  'DR': 0.02223675604970569,
#  'DK': 0.02158273381294964,
#  'NH': 0.02158273381294964,
#  'LN': 0.020274689339437543,
#  'KR': 0.020274689339437543,
#  'SP': 0.01765860039241334,
#  'LS': 0.012426422498364944,
#  'KM': 0.011772400261608895,
#  'RG': 0.005232177894048398,
#  'AG': 0.002616088947024199,
#  'RK': 0.0006540222367560497,
#  'GR': 0.0}

# %%
RGP = ProbDist(
    LH = 296, VB = 231, CL = 200, MV = 200, SV = 194, PG = 69, CS = 58, AA = 42, DR = 34, DK = 33,
    NH = 33, LN = 31, KR = 31, SP = 27, LS = 19, KM = 18, RG = 8, AG = 4, RK = 1, GR = 0,
    )
RGP
# Out:
# {'LH': 0.1935905820797907,
#  'VB': 0.1510791366906475,
#  'CL': 0.13080444735120994,
#  'MV': 0.13080444735120994,
#  'SV': 0.12688031393067364,
#  'PG': 0.04512753433616743,
#  'CS': 0.03793328973185088,
#  'AA': 0.027468933943754086,
#  'DR': 0.02223675604970569,
#  'DK': 0.02158273381294964,
#  'NH': 0.02158273381294964,
#  'LN': 0.020274689339437543,
#  'KR': 0.020274689339437543,
#  'SP': 0.01765860039241334,
#  'LS': 0.012426422498364944,
#  'KM': 0.011772400261608895,
#  'RG': 0.005232177894048398,
#  'AG': 0.002616088947024199,
#  'RK': 0.0006540222367560497,
#  'GR': 0.0}

# %% [markdown]
# #### What is the Probability Distribution for each F1 driver to win both the Singaporean and Russian Grand Prix?

# %%
SRGP = joint(SGP, RGP, ' ')

SRGP['LH LH'] , SRGP['VB VB'], SRGP['CL CL'] , SRGP['MV MV'], SRGP['PG PG'] , SRGP['CS CS'], SRGP['AA AA'] , SRGP['DR DR'], SRGP['DK DK'] , SRGP['NH NH'], SRGP['LN LN'] , SRGP['SP SP'], SRGP['LS LS'] , SRGP['KM KM'], SRGP['RG RG'] , SRGP['AG AG'], SRGP['RK RK'] , SRGP['GR GR']
# Out:
# (0.03747731346999217,
#  0.02282490554319134,
#  0.017109803446855445,
#  0.017109803446855445,
#  0.0020364943552619694,
#  0.001438934469880543,
#  0.0007545423320063251,
#  0.0004944733196141224,
#  0.00046581439884063955,
#  0.00046581439884063955,
#  0.0004110630278107022,
#  0.00031182616781894046,
#  0.00015441597610787037,
#  0.00013858940791952913,
#  2.7375685514968715e-05,
#  6.843921378742179e-06,
#  4.277450861713862e-07,
#  0.0)

# %%
CAR =  ProbDist(
    MER = 527, FER = 394, RED = 242, SCU = 102, MCL = 89,  REN = 67, ALF = 35, RAC = 46, HAA = 26, WIL = 1
    )
MerWinFirst = CAR['MER']
MerWinFirst
# Out:
# 0.34466971877043817

# %% [markdown]
# #### What is the probability for Mercedes to win both races?

# %%
CAR2 =  ProbDist(
     MER = 527, FER = 394, RED = 242, SCU = 102, MCL = 89,  REN = 67, ALF = 35, RAC = 46,HAA = 26, WIL = 1
    )
MerWinSecond = CAR2['MER']
CarGame2 = joint(CAR, CAR2, ' ')

CarGame2['MER MER']
# Out:
# 0.11879721503729297

# %% [markdown]
# #### What is the probability for Mercedes to win at least one race?

# %%
CarLeast1 = MerWinFirst * (1 - MerWinFirst) + MerWinSecond * (1 - MerWinSecond) + MerWinFirst*MerWinSecond
CarLeast1
# Out:
# 0.5705422225035834

# %%
p(atleast1, CarGame2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-51b3c3e75f4c> in <module>
# ----> 1 p(atleast1, CarGame2)
#
# NameError: name 'atleast1' is not defined

# %%
def first_Mer(outcome):  return outcome[0:3] == 'MER'
def first_Fer(outcome):  return outcome[0:3] == 'FER'
def first_Red(outcome):  return outcome[0:3] == 'RED'
def first_Ren(outcome):  return outcome[0:3] == 'REN'
def second_Mer(outcome): return outcome[4:] == 'MER'
def second_Fer(outcome): return outcome[4:] == 'FER'
def second_Red(outcome): return outcome[4:] == 'RED'
def second_Ren(outcome): return outcome[4:] == 'REN'
def bothwin(outcome):return outcome=='MER MER'
def bothwinFer(outcome):return outcome=='FER FER'
def bothwinRed(outcome):return outcome=='RED RED'
def bothwinRen(outcome):return outcome=='REN REN'
def atleast1(outcome): return 'MER' in outcome 
def atleastFer(outcome): return 'FER' in outcome 
def atleastRed(outcome): return 'RED' in outcome 
def atleastRen(outcome): return 'REN' in outcome

# %% [markdown]
# #### If Mercedes wins the first race, what is the probability that Mercedes wins the next one?

# %%
p(second_Mer, such_that(first_Mer,CarGame2))
# Out:
# 0.3446697187704383

# %% [markdown]
# #### Ferrari wins the first race, what is the probability that Mercedes wins the next one?

# %%
Ferrari_First_Win = p(second_Fer, such_that(first_Fer,CarGame2))
Ferrari_First_Win
# Out:
# 0.2576847612818836

# %% [markdown]
# #### Red Bull wins the first race, what is the probability that Mercedes wins the next one?

# %%
Red_Bull_First_Win = p(second_Red, such_that(first_Red,CarGame2))
Red_Bull_First_Win
# Out:
# 0.15827338129496404

# %% [markdown]
# #### Renault wins the first race, what is the probability that Mercedes wins the next one?

# %%
Renault_First_Win = p(second_Ren, such_that(first_Ren,CarGame2))
Renault_First_Win
# Out:
# 0.04381948986265533

# %%
such_that(first_Mer,CarGame2)
# Out:
# {'MER MER': 0.3446697187704383,
#  'MER FER': 0.25768476128188356,
#  'MER RED': 0.15827338129496407,
#  'MER SCU': 0.06671026814911708,
#  'MER MCL': 0.05820797907128844,
#  'MER REN': 0.04381948986265534,
#  'MER ALF': 0.022890778286461744,
#  'MER RAC': 0.03008502289077829,
#  'MER HAA': 0.017004578155657295,
#  'MER WIL': 0.0006540222367560499}

# %% [markdown]
# #### If Mercedes wins at least one of these two races, what is the probability Mercedes wins both races?

# %%
p(bothwin,such_that(atleast1,CarGame2))
# Out:
# 0.2082180956143817

# %%
weather = ProbDist(rainy = 1, sunny = 1,  cloudy = 1,  snowy = 1, foggy = 1)

# %%
Game_Weather_1=joint(CAR, weather, ' ')

# %%
Game_Weather_2=joint(CAR2, weather, ' ')

# %%
Game_weather_all = joint(Game_Weather_1, Game_Weather_2, ' ')

# %%
Game_weather_all
# Out:
# {'MER rainy MER rainy': 0.004751888601491754,
#  'MER rainy MER sunny': 0.004751888601491754,
#  'MER rainy MER cloudy': 0.004751888601491754,
#  'MER rainy MER snowy': 0.004751888601491754,
#  'MER rainy MER foggy': 0.004751888601491754,
#  'MER rainy FER rainy': 0.0035526453680981996,
#  'MER rainy FER sunny': 0.0035526453680981996,
#  'MER rainy FER cloudy': 0.0035526453680981996,
#  'MER rainy FER snowy': 0.0035526453680981996,
#  'MER rainy FER foggy': 0.0035526453680981996,
#  'MER rainy RED rainy': 0.0021820816727912804,
#  'MER rainy RED sunny': 0.0021820816727912804,
#  'MER rainy RED cloudy': 0.0021820816727912804,
#  'MER rainy RED snowy': 0.0021820816727912804,
#  'MER rainy RED foggy': 0.0021820816727912804,
#  'MER rainy SCU rainy': 0.0009197203744822751,
#  'MER rainy SCU sunny': 0.0009197203744822751,
#  'MER rainy SCU cloudy': 0.0009197203744822751,
#  'MER rainy SCU snowy': 0.0009197203744822751,
#  'MER rainy SCU foggy': 0.0009197203744822751,
#  'MER rainy MCL rainy': 0.0008025011110678676,
#  'MER rainy MCL sunny': 0.0008025011110678676,
#  'MER rainy MCL cloudy': 0.0008025011110678676,
#  'MER rainy MCL snowy': 0.0008025011110678676,
#  'MER rainy MCL foggy': 0.0008025011110678676,
#  'MER rainy REN rainy': 0.0006041300499050239,
#  'MER rainy REN sunny': 0.0006041300499050239,
#  'MER rainy REN cloudy': 0.0006041300499050239,
#  'MER rainy REN snowy': 0.0006041300499050239,
#  'MER rainy REN foggy': 0.0006041300499050239,
#  'MER rainy ALF rainy': 0.0003155903245772513,
#  'MER rainy ALF sunny': 0.0003155903245772513,
#  'MER rainy ALF cloudy': 0.0003155903245772513,
#  'MER rainy ALF snowy': 0.0003155903245772513,
#  'MER rainy ALF foggy': 0.0003155903245772513,
#  'MER rainy RAC rainy': 0.00041477585515867313,
#  'MER rainy RAC sunny': 0.00041477585515867313,
#  'MER rainy RAC cloudy': 0.00041477585515867313,
#  'MER rainy RAC snowy': 0.00041477585515867313,
#  'MER rainy RAC foggy': 0.00041477585515867313,
#  'MER rainy HAA rainy': 0.00023443852682881523,
#  'MER rainy HAA sunny': 0.00023443852682881523,
#  'MER rainy HAA cloudy': 0.00023443852682881523,
#  'MER rainy HAA snowy': 0.00023443852682881523,
#  'MER rainy HAA foggy': 0.00023443852682881523,
#  'MER rainy WIL rainy': 9.016866416492895e-06,
#  'MER rainy WIL sunny': 9.016866416492895e-06,
#  'MER rainy WIL cloudy': 9.016866416492895e-06,
#  'MER rainy WIL snowy': 9.016866416492895e-06,
#  'MER rainy WIL foggy': 9.016866416492895e-06,
#  'MER sunny MER rainy': 0.004751888601491754,
#  'MER sunny MER sunny': 0.004751888601491754,
#  'MER sunny MER cloudy': 0.004751888601491754,
#  'MER sunny MER snowy': 0.004751888601491754,
#  'MER sunny MER foggy': 0.004751888601491754,
#  'MER sunny FER rainy': 0.0035526453680981996,
#  'MER sunny FER sunny': 0.0035526453680981996,
#  'MER sunny FER cloudy': 0.0035526453680981996,
#  'MER sunny FER snowy': 0.0035526453680981996,
#  'MER sunny FER foggy': 0.0035526453680981996,
#  'MER sunny RED rainy': 0.0021820816727912804,
#  'MER sunny RED sunny': 0.0021820816727912804,
#  'MER sunny RED cloudy': 0.0021820816727912804,
#  'MER sunny RED snowy': 0.0021820816727912804,
#  'MER sunny RED foggy': 0.0021820816727912804,
#  'MER sunny SCU rainy': 0.0009197203744822751,
#  'MER sunny SCU sunny': 0.0009197203744822751,
#  'MER sunny SCU cloudy': 0.0009197203744822751,
#  'MER sunny SCU snowy': 0.0009197203744822751,
#  'MER sunny SCU foggy': 0.0009197203744822751,
#  'MER sunny MCL rainy': 0.0008025011110678676,
#  'MER sunny MCL sunny': 0.0008025011110678676,
#  'MER sunny MCL cloudy': 0.0008025011110678676,
#  'MER sunny MCL snowy': 0.0008025011110678676,
#  'MER sunny MCL foggy': 0.0008025011110678676,
#  'MER sunny REN rainy': 0.0006041300499050239,
#  'MER sunny REN sunny': 0.0006041300499050239,
#  'MER sunny REN cloudy': 0.0006041300499050239,
#  'MER sunny REN snowy': 0.0006041300499050239,
#  'MER sunny REN foggy': 0.0006041300499050239,
#  'MER sunny ALF rainy': 0.0003155903245772513,
#  'MER sunny ALF sunny': 0.0003155903245772513,
#  'MER sunny ALF cloudy': 0.0003155903245772513,
#  'MER sunny ALF snowy': 0.0003155903245772513,
#  'MER sunny ALF foggy': 0.0003155903245772513,
#  'MER sunny RAC rainy': 0.00041477585515867313,
#  'MER sunny RAC sunny': 0.00041477585515867313,
#  'MER sunny RAC cloudy': 0.00041477585515867313,
#  'MER sunny RAC snowy': 0.00041477585515867313,
#  'MER sunny RAC foggy': 0.00041477585515867313,
#  'MER sunny HAA rainy': 0.00023443852682881523,
#  'MER sunny HAA sunny': 0.00023443852682881523,
#  'MER sunny HAA cloudy': 0.00023443852682881523,
#  'MER sunny HAA snowy': 0.00023443852682881523,
#  'MER sunny HAA foggy': 0.00023443852682881523,
#  'MER sunny WIL rainy': 9.016866416492895e-06,
#  'MER sunny WIL sunny': 9.016866416492895e-06,
#  'MER sunny WIL cloudy': 9.016866416492895e-06,
#  'MER sunny WIL snowy': 9.016866416492895e-06,
#  'MER sunny WIL foggy': 9.016866416492895e-06,
#  'MER cloudy MER rainy': 0.004751888601491754,
#  'MER cloudy MER sunny': 0.004751888601491754,
#  'MER cloudy MER cloudy': 0.004751888601491754,
#  'MER cloudy MER snowy': 0.004751888601491754,
#  'MER cloudy MER foggy': 0.004751888601491754,
#  'MER cloudy FER rainy': 0.0035526453680981996,
#  'MER cloudy FER sunny': 0.0035526453680981996,
#  'MER cloudy FER cloudy': 0.0035526453680981996,
#  'MER cloudy FER snowy': 0.0035526453680981996,
#  'MER cloudy FER foggy': 0.0035526453680981996,
#  'MER cloudy RED rainy': 0.0021820816727912804,
#  'MER cloudy RED sunny': 0.0021820816727912804,
#  'MER cloudy RED cloudy': 0.0021820816727912804,
#  'MER cloudy RED snowy': 0.0021820816727912804,
#  'MER cloudy RED foggy': 0.0021820816727912804,
#  'MER cloudy SCU rainy': 0.0009197203744822751,
#  'MER cloudy SCU sunny': 0.0009197203744822751,
#  'MER cloudy SCU cloudy': 0.0009197203744822751,
#  'MER cloudy SCU snowy': 0.0009197203744822751,
#  'MER cloudy SCU foggy': 0.0009197203744822751,
#  'MER cloudy MCL rainy': 0.0008025011110678676,
#  'MER cloudy MCL sunny': 0.0008025011110678676,
#  'MER cloudy MCL cloudy': 0.0008025011110678676,
#  'MER cloudy MCL snowy': 0.0008025011110678676,
#  'MER cloudy MCL foggy': 0.0008025011110678676,
#  'MER cloudy REN rainy': 0.0006041300499050239,
#  'MER cloudy REN sunny': 0.0006041300499050239,
#  'MER cloudy REN cloudy': 0.0006041300499050239,
#  'MER cloudy REN snowy': 0.0006041300499050239,
#  'MER cloudy REN foggy': 0.0006041300499050239,
#  'MER cloudy ALF rainy': 0.0003155903245772513,
#  'MER cloudy ALF sunny': 0.0003155903245772513,
#  'MER cloudy ALF cloudy': 0.0003155903245772513,
#  'MER cloudy ALF snowy': 0.0003155903245772513,
#  'MER cloudy ALF foggy': 0.0003155903245772513,
#  'MER cloudy RAC rainy': 0.00041477585515867313,
#  'MER cloudy RAC sunny': 0.00041477585515867313,
#  'MER cloudy RAC cloudy': 0.00041477585515867313,
#  'MER cloudy RAC snowy': 0.00041477585515867313,
#  'MER cloudy RAC foggy': 0.00041477585515867313,
#  'MER cloudy HAA rainy': 0.00023443852682881523,
#  'MER cloudy HAA sunny': 0.00023443852682881523,
#  'MER cloudy HAA cloudy': 0.00023443852682881523,
#  'MER cloudy HAA snowy': 0.00023443852682881523,
#  'MER cloudy HAA foggy': 0.00023443852682881523,
#  'MER cloudy WIL rainy': 9.016866416492895e-06,
#  'MER cloudy WIL sunny': 9.016866416492895e-06,
#  'MER cloudy WIL cloudy': 9.016866416492895e-06,
#  'MER cloudy WIL snowy': 9.016866416492895e-06,
#  'MER cloudy WIL foggy': 9.016866416492895e-06,
#  'MER snowy MER rainy': 0.004751888601491754,
#  'MER snowy MER sunny': 0.004751888601491754,
#  'MER snowy MER cloudy': 0.004751888601491754,
#  'MER snowy MER snowy': 0.004751888601491754,
#  'MER snowy MER foggy': 0.004751888601491754,
#  'MER snowy FER rainy': 0.0035526453680981996,
#  'MER snowy FER sunny': 0.0035526453680981996,
#  'MER snowy FER cloudy': 0.0035526453680981996,
#  'MER snowy FER snowy': 0.0035526453680981996,
#  'MER snowy FER foggy': 0.0035526453680981996,
#  'MER snowy RED rainy': 0.0021820816727912804,
#  'MER snowy RED sunny': 0.0021820816727912804,
#  'MER snowy RED cloudy': 0.0021820816727912804,
#  'MER snowy RED snowy': 0.0021820816727912804,
#  'MER snowy RED foggy': 0.0021820816727912804,
#  'MER snowy SCU rainy': 0.0009197203744822751,
#  'MER snowy SCU sunny': 0.0009197203744822751,
#  'MER snowy SCU cloudy': 0.0009197203744822751,
#  'MER snowy SCU snowy': 0.0009197203744822751,
#  'MER snowy SCU foggy': 0.0009197203744822751,
#  'MER snowy MCL rainy': 0.0008025011110678676,
#  'MER snowy MCL sunny': 0.0008025011110678676,
#  'MER snowy MCL cloudy': 0.0008025011110678676,
#  'MER snowy MCL snowy': 0.0008025011110678676,
#  'MER snowy MCL foggy': 0.0008025011110678676,
#  'MER snowy REN rainy': 0.0006041300499050239,
#  'MER snowy REN sunny': 0.0006041300499050239,
#  'MER snowy REN cloudy': 0.0006041300499050239,
#  'MER snowy REN snowy': 0.0006041300499050239,
#  'MER snowy REN foggy': 0.0006041300499050239,
#  'MER snowy ALF rainy': 0.0003155903245772513,
#  'MER snowy ALF sunny': 0.0003155903245772513,
#  'MER snowy ALF cloudy': 0.0003155903245772513,
#  'MER snowy ALF snowy': 0.0003155903245772513,
#  'MER snowy ALF foggy': 0.0003155903245772513,
#  'MER snowy RAC rainy': 0.00041477585515867313,
#  'MER snowy RAC sunny': 0.00041477585515867313,
#  'MER snowy RAC cloudy': 0.00041477585515867313,
#  'MER snowy RAC snowy': 0.00041477585515867313,
#  'MER snowy RAC foggy': 0.00041477585515867313,
#  'MER snowy HAA rainy': 0.00023443852682881523,
#  'MER snowy HAA sunny': 0.00023443852682881523,
#  'MER snowy HAA cloudy': 0.00023443852682881523,
#  'MER snowy HAA snowy': 0.00023443852682881523,
#  'MER snowy HAA foggy': 0.00023443852682881523,
#  'MER snowy WIL rainy': 9.016866416492895e-06,
#  'MER snowy WIL sunny': 9.016866416492895e-06,
#  'MER snowy WIL cloudy': 9.016866416492895e-06,
#  'MER snowy WIL snowy': 9.016866416492895e-06,
#  'MER snowy WIL foggy': 9.016866416492895e-06,
#  'MER foggy MER rainy': 0.004751888601491754,
#  'MER foggy MER sunny': 0.004751888601491754,
#  'MER foggy MER cloudy': 0.004751888601491754,
#  'MER foggy MER snowy': 0.004751888601491754,
#  'MER foggy MER foggy': 0.004751888601491754,
#  'MER foggy FER rainy': 0.0035526453680981996,
#  'MER foggy FER sunny': 0.0035526453680981996,
#  'MER foggy FER cloudy': 0.0035526453680981996,
#  'MER foggy FER snowy': 0.0035526453680981996,
#  'MER foggy FER foggy': 0.0035526453680981996,
#  'MER foggy RED rainy': 0.0021820816727912804,
#  'MER foggy RED sunny': 0.0021820816727912804,
#  'MER foggy RED cloudy': 0.0021820816727912804,
#  'MER foggy RED snowy': 0.0021820816727912804,
#  'MER foggy RED foggy': 0.0021820816727912804,
#  'MER foggy SCU rainy': 0.0009197203744822751,
#  'MER foggy SCU sunny': 0.0009197203744822751,
#  'MER foggy SCU cloudy': 0.0009197203744822751,
#  'MER foggy SCU snowy': 0.0009197203744822751,
#  'MER foggy SCU foggy': 0.0009197203744822751,
#  'MER foggy MCL rainy': 0.0008025011110678676,
#  'MER foggy MCL sunny': 0.0008025011110678676,
#  'MER foggy MCL cloudy': 0.0008025011110678676,
#  'MER foggy MCL snowy': 0.0008025011110678676,
#  'MER foggy MCL foggy': 0.0008025011110678676,
#  'MER foggy REN rainy': 0.0006041300499050239,
#  'MER foggy REN sunny': 0.0006041300499050239,
#  'MER foggy REN cloudy': 0.0006041300499050239,
#  'MER foggy REN snowy': 0.0006041300499050239,
#  'MER foggy REN foggy': 0.0006041300499050239,
#  'MER foggy ALF rainy': 0.0003155903245772513,
#  'MER foggy ALF sunny': 0.0003155903245772513,
#  'MER foggy ALF cloudy': 0.0003155903245772513,
#  'MER foggy ALF snowy': 0.0003155903245772513,
#  'MER foggy ALF foggy': 0.0003155903245772513,
#  'MER foggy RAC rainy': 0.00041477585515867313,
#  'MER foggy RAC sunny': 0.00041477585515867313,
#  'MER foggy RAC cloudy': 0.00041477585515867313,
#  'MER foggy RAC snowy': 0.00041477585515867313,
#  'MER foggy RAC foggy': 0.00041477585515867313,
#  'MER foggy HAA rainy': 0.00023443852682881523,
#  'MER foggy HAA sunny': 0.00023443852682881523,
#  'MER foggy HAA cloudy': 0.00023443852682881523,
#  'MER foggy HAA snowy': 0.00023443852682881523,
#  'MER foggy HAA foggy': 0.00023443852682881523,
#  'MER foggy WIL rainy': 9.016866416492895e-06,
#  'MER foggy WIL sunny': 9.016866416492895e-06,
#  'MER foggy WIL cloudy': 9.016866416492895e-06,
#  'MER foggy WIL snowy': 9.016866416492895e-06,
#  'MER foggy WIL foggy': 9.016866416492895e-06,
#  'FER rainy MER rainy': 0.0035526453680981996,
#  'FER rainy MER sunny': 0.0035526453680981996,
#  'FER rainy MER cloudy': 0.0035526453680981996,
#  'FER rainy MER snowy': 0.0035526453680981996,
#  'FER rainy MER foggy': 0.0035526453680981996,
#  'FER rainy FER rainy': 0.0026560574478760733,
#  'FER rainy FER sunny': 0.0026560574478760733,
#  'FER rainy FER cloudy': 0.0026560574478760733,
#  'FER rainy FER snowy': 0.0026560574478760733,
#  'FER rainy FER foggy': 0.0026560574478760733,
#  'FER rainy RED rainy': 0.0016313855390507862,
#  'FER rainy RED sunny': 0.0016313855390507862,
#  'FER rainy RED cloudy': 0.0016313855390507862,
#  'FER rainy RED snowy': 0.0016313855390507862,
#  'FER rainy RED foggy': 0.0016313855390507862,
#  'FER rainy SCU rainy': 0.0006876087809222322,
#  'FER rainy SCU sunny': 0.0006876087809222322,
#  'FER rainy SCU cloudy': 0.0006876087809222322,
#  'FER rainy SCU snowy': 0.0006876087809222322,
#  'FER rainy SCU foggy': 0.0006876087809222322,
#  'FER rainy MCL rainy': 0.000599972367667438,
#  'FER rainy MCL sunny': 0.000599972367667438,
#  'FER rainy MCL cloudy': 0.000599972367667438,
#  'FER rainy MCL snowy': 0.000599972367667438,
#  'FER rainy MCL foggy': 0.000599972367667438,
#  'FER rainy REN rainy': 0.0004516645913900938,
#  'FER rainy REN sunny': 0.0004516645913900938,
#  'FER rainy REN cloudy': 0.0004516645913900938,
#  'FER rainy REN snowy': 0.0004516645913900938,
#  'FER rainy REN foggy': 0.0004516645913900938,
#  'FER rainy ALF rainy': 0.00023594418953213855,
#  'FER rainy ALF sunny': 0.00023594418953213855,
#  'FER rainy ALF cloudy': 0.00023594418953213855,
#  'FER rainy ALF snowy': 0.00023594418953213855,
#  'FER rainy ALF foggy': 0.00023594418953213855,
#  'FER rainy RAC rainy': 0.0003100980776708106,
#  'FER rainy RAC sunny': 0.0003100980776708106,
#  'FER rainy RAC cloudy': 0.0003100980776708106,
#  'FER rainy RAC snowy': 0.0003100980776708106,
#  'FER rainy RAC foggy': 0.0003100980776708106,
#  'FER rainy HAA rainy': 0.00017527282650958858,
#  'FER rainy HAA sunny': 0.00017527282650958858,
#  'FER rainy HAA cloudy': 0.00017527282650958858,
#  'FER rainy HAA snowy': 0.00017527282650958858,
#  'FER rainy HAA foggy': 0.00017527282650958858,
#  'FER rainy WIL rainy': 6.741262558061102e-06,
#  'FER rainy WIL sunny': 6.741262558061102e-06,
#  'FER rainy WIL cloudy': 6.741262558061102e-06,
#  'FER rainy WIL snowy': 6.741262558061102e-06,
#  'FER rainy WIL foggy': 6.741262558061102e-06,
#  'FER sunny MER rainy': 0.0035526453680981996,
#  'FER sunny MER sunny': 0.0035526453680981996,
#  'FER sunny MER cloudy': 0.0035526453680981996,
#  'FER sunny MER snowy': 0.0035526453680981996,
#  'FER sunny MER foggy': 0.0035526453680981996,
#  'FER sunny FER rainy': 0.0026560574478760733,
#  'FER sunny FER sunny': 0.0026560574478760733,
#  'FER sunny FER cloudy': 0.0026560574478760733,
#  'FER sunny FER snowy': 0.0026560574478760733,
#  'FER sunny FER foggy': 0.0026560574478760733,
#  'FER sunny RED rainy': 0.0016313855390507862,
#  'FER sunny RED sunny': 0.0016313855390507862,
#  'FER sunny RED cloudy': 0.0016313855390507862,
#  'FER sunny RED snowy': 0.0016313855390507862,
#  'FER sunny RED foggy': 0.0016313855390507862,
#  'FER sunny SCU rainy': 0.0006876087809222322,
#  'FER sunny SCU sunny': 0.0006876087809222322,
#  'FER sunny SCU cloudy': 0.0006876087809222322,
#  'FER sunny SCU snowy': 0.0006876087809222322,
#  'FER sunny SCU foggy': 0.0006876087809222322,
#  'FER sunny MCL rainy': 0.000599972367667438,
#  'FER sunny MCL sunny': 0.000599972367667438,
#  'FER sunny MCL cloudy': 0.000599972367667438,
#  'FER sunny MCL snowy': 0.000599972367667438,
#  'FER sunny MCL foggy': 0.000599972367667438,
#  'FER sunny REN rainy': 0.0004516645913900938,
#  'FER sunny REN sunny': 0.0004516645913900938,
#  'FER sunny REN cloudy': 0.0004516645913900938,
#  'FER sunny REN snowy': 0.0004516645913900938,
#  'FER sunny REN foggy': 0.0004516645913900938,
#  'FER sunny ALF rainy': 0.00023594418953213855,
#  'FER sunny ALF sunny': 0.00023594418953213855,
#  'FER sunny ALF cloudy': 0.00023594418953213855,
#  'FER sunny ALF snowy': 0.00023594418953213855,
#  'FER sunny ALF foggy': 0.00023594418953213855,
#  'FER sunny RAC rainy': 0.0003100980776708106,
#  'FER sunny RAC sunny': 0.0003100980776708106,
#  'FER sunny RAC cloudy': 0.0003100980776708106,
#  'FER sunny RAC snowy': 0.0003100980776708106,
#  'FER sunny RAC foggy': 0.0003100980776708106,
#  'FER sunny HAA rainy': 0.00017527282650958858,
#  'FER sunny HAA sunny': 0.00017527282650958858,
#  'FER sunny HAA cloudy': 0.00017527282650958858,
#  'FER sunny HAA snowy': 0.00017527282650958858,
#  'FER sunny HAA foggy': 0.00017527282650958858,
#  'FER sunny WIL rainy': 6.741262558061102e-06,
#  'FER sunny WIL sunny': 6.741262558061102e-06,
#  'FER sunny WIL cloudy': 6.741262558061102e-06,
#  'FER sunny WIL snowy': 6.741262558061102e-06,
#  'FER sunny WIL foggy': 6.741262558061102e-06,
#  'FER cloudy MER rainy': 0.0035526453680981996,
#  'FER cloudy MER sunny': 0.0035526453680981996,
#  'FER cloudy MER cloudy': 0.0035526453680981996,
#  'FER cloudy MER snowy': 0.0035526453680981996,
#  'FER cloudy MER foggy': 0.0035526453680981996,
#  'FER cloudy FER rainy': 0.0026560574478760733,
#  'FER cloudy FER sunny': 0.0026560574478760733,
#  'FER cloudy FER cloudy': 0.0026560574478760733,
#  'FER cloudy FER snowy': 0.0026560574478760733,
#  'FER cloudy FER foggy': 0.0026560574478760733,
#  'FER cloudy RED rainy': 0.0016313855390507862,
#  'FER cloudy RED sunny': 0.0016313855390507862,
#  'FER cloudy RED cloudy': 0.0016313855390507862,
#  'FER cloudy RED snowy': 0.0016313855390507862,
#  'FER cloudy RED foggy': 0.0016313855390507862,
#  'FER cloudy SCU rainy': 0.0006876087809222322,
#  'FER cloudy SCU sunny': 0.0006876087809222322,
#  'FER cloudy SCU cloudy': 0.0006876087809222322,
#  'FER cloudy SCU snowy': 0.0006876087809222322,
#  'FER cloudy SCU foggy': 0.0006876087809222322,
#  'FER cloudy MCL rainy': 0.000599972367667438,
#  'FER cloudy MCL sunny': 0.000599972367667438,
#  'FER cloudy MCL cloudy': 0.000599972367667438,
#  'FER cloudy MCL snowy': 0.000599972367667438,
#  'FER cloudy MCL foggy': 0.000599972367667438,
#  'FER cloudy REN rainy': 0.0004516645913900938,
#  'FER cloudy REN sunny': 0.0004516645913900938,
#  'FER cloudy REN cloudy': 0.0004516645913900938,
#  'FER cloudy REN snowy': 0.0004516645913900938,
#  'FER cloudy REN foggy': 0.0004516645913900938,
#  'FER cloudy ALF rainy': 0.00023594418953213855,
#  'FER cloudy ALF sunny': 0.00023594418953213855,
#  'FER cloudy ALF cloudy': 0.00023594418953213855,
#  'FER cloudy ALF snowy': 0.00023594418953213855,
#  'FER cloudy ALF foggy': 0.00023594418953213855,
#  'FER cloudy RAC rainy': 0.0003100980776708106,
#  'FER cloudy RAC sunny': 0.0003100980776708106,
#  'FER cloudy RAC cloudy': 0.0003100980776708106,
#  'FER cloudy RAC snowy': 0.0003100980776708106,
#  'FER cloudy RAC foggy': 0.0003100980776708106,
#  'FER cloudy HAA rainy': 0.00017527282650958858,
#  'FER cloudy HAA sunny': 0.00017527282650958858,
#  'FER cloudy HAA cloudy': 0.00017527282650958858,
#  'FER cloudy HAA snowy': 0.00017527282650958858,
#  'FER cloudy HAA foggy': 0.00017527282650958858,
#  'FER cloudy WIL rainy': 6.741262558061102e-06,
#  'FER cloudy WIL sunny': 6.741262558061102e-06,
#  'FER cloudy WIL cloudy': 6.741262558061102e-06,
#  'FER cloudy WIL snowy': 6.741262558061102e-06,
#  'FER cloudy WIL foggy': 6.741262558061102e-06,
#  'FER snowy MER rainy': 0.0035526453680981996,
#  'FER snowy MER sunny': 0.0035526453680981996,
#  'FER snowy MER cloudy': 0.0035526453680981996,
#  'FER snowy MER snowy': 0.0035526453680981996,
#  'FER snowy MER foggy': 0.0035526453680981996,
#  'FER snowy FER rainy': 0.0026560574478760733,
#  'FER snowy FER sunny': 0.0026560574478760733,
#  'FER snowy FER cloudy': 0.0026560574478760733,
#  'FER snowy FER snowy': 0.0026560574478760733,
#  'FER snowy FER foggy': 0.0026560574478760733,
#  'FER snowy RED rainy': 0.0016313855390507862,
#  'FER snowy RED sunny': 0.0016313855390507862,
#  'FER snowy RED cloudy': 0.0016313855390507862,
#  'FER snowy RED snowy': 0.0016313855390507862,
#  'FER snowy RED foggy': 0.0016313855390507862,
#  'FER snowy SCU rainy': 0.0006876087809222322,
#  'FER snowy SCU sunny': 0.0006876087809222322,
#  'FER snowy SCU cloudy': 0.0006876087809222322,
#  'FER snowy SCU snowy': 0.0006876087809222322,
#  'FER snowy SCU foggy': 0.0006876087809222322,
#  'FER snowy MCL rainy': 0.000599972367667438,
#  'FER snowy MCL sunny': 0.000599972367667438,
#  'FER snowy MCL cloudy': 0.000599972367667438,
#  'FER snowy MCL snowy': 0.000599972367667438,
#  'FER snowy MCL foggy': 0.000599972367667438,
#  'FER snowy REN rainy': 0.0004516645913900938,
#  'FER snowy REN sunny': 0.0004516645913900938,
#  'FER snowy REN cloudy': 0.0004516645913900938,
#  'FER snowy REN snowy': 0.0004516645913900938,
#  'FER snowy REN foggy': 0.0004516645913900938,
#  'FER snowy ALF rainy': 0.00023594418953213855,
#  'FER snowy ALF sunny': 0.00023594418953213855,
#  'FER snowy ALF cloudy': 0.00023594418953213855,
#  'FER snowy ALF snowy': 0.00023594418953213855,
#  'FER snowy ALF foggy': 0.00023594418953213855,
#  'FER snowy RAC rainy': 0.0003100980776708106,
#  'FER snowy RAC sunny': 0.0003100980776708106,
#  'FER snowy RAC cloudy': 0.0003100980776708106,
#  'FER snowy RAC snowy': 0.0003100980776708106,
#  'FER snowy RAC foggy': 0.0003100980776708106,
#  'FER snowy HAA rainy': 0.00017527282650958858,
#  'FER snowy HAA sunny': 0.00017527282650958858,
#  'FER snowy HAA cloudy': 0.00017527282650958858,
#  'FER snowy HAA snowy': 0.00017527282650958858,
#  'FER snowy HAA foggy': 0.00017527282650958858,
#  'FER snowy WIL rainy': 6.741262558061102e-06,
#  'FER snowy WIL sunny': 6.741262558061102e-06,
#  'FER snowy WIL cloudy': 6.741262558061102e-06,
#  'FER snowy WIL snowy': 6.741262558061102e-06,
#  'FER snowy WIL foggy': 6.741262558061102e-06,
#  'FER foggy MER rainy': 0.0035526453680981996,
#  'FER foggy MER sunny': 0.0035526453680981996,
#  'FER foggy MER cloudy': 0.0035526453680981996,
#  'FER foggy MER snowy': 0.0035526453680981996,
#  'FER foggy MER foggy': 0.0035526453680981996,
#  'FER foggy FER rainy': 0.0026560574478760733,
#  'FER foggy FER sunny': 0.0026560574478760733,
#  'FER foggy FER cloudy': 0.0026560574478760733,
#  'FER foggy FER snowy': 0.0026560574478760733,
#  'FER foggy FER foggy': 0.0026560574478760733,
#  'FER foggy RED rainy': 0.0016313855390507862,
#  'FER foggy RED sunny': 0.0016313855390507862,
#  'FER foggy RED cloudy': 0.0016313855390507862,
#  'FER foggy RED snowy': 0.0016313855390507862,
#  'FER foggy RED foggy': 0.0016313855390507862,
#  'FER foggy SCU rainy': 0.0006876087809222322,
#  'FER foggy SCU sunny': 0.0006876087809222322,
#  'FER foggy SCU cloudy': 0.0006876087809222322,
#  'FER foggy SCU snowy': 0.0006876087809222322,
#  'FER foggy SCU foggy': 0.0006876087809222322,
#  'FER foggy MCL rainy': 0.000599972367667438,
#  'FER foggy MCL sunny': 0.000599972367667438,
#  'FER foggy MCL cloudy': 0.000599972367667438,
#  'FER foggy MCL snowy': 0.000599972367667438,
#  'FER foggy MCL foggy': 0.000599972367667438,
#  'FER foggy REN rainy': 0.0004516645913900938,
#  'FER foggy REN sunny': 0.0004516645913900938,
#  'FER foggy REN cloudy': 0.0004516645913900938,
#  'FER foggy REN snowy': 0.0004516645913900938,
#  'FER foggy REN foggy': 0.0004516645913900938,
#  'FER foggy ALF rainy': 0.00023594418953213855,
#  'FER foggy ALF sunny': 0.00023594418953213855,
#  'FER foggy ALF cloudy': 0.00023594418953213855,
#  'FER foggy ALF snowy': 0.00023594418953213855,
#  'FER foggy ALF foggy': 0.00023594418953213855,
#  'FER foggy RAC rainy': 0.0003100980776708106,
#  'FER foggy RAC sunny': 0.0003100980776708106,
#  'FER foggy RAC cloudy': 0.0003100980776708106,
#  'FER foggy RAC snowy': 0.0003100980776708106,
#  'FER foggy RAC foggy': 0.0003100980776708106,
#  'FER foggy HAA rainy': 0.00017527282650958858,
#  'FER foggy HAA sunny': 0.00017527282650958858,
#  'FER foggy HAA cloudy': 0.00017527282650958858,
#  'FER foggy HAA snowy': 0.00017527282650958858,
#  'FER foggy HAA foggy': 0.00017527282650958858,
#  'FER foggy WIL rainy': 6.741262558061102e-06,
#  'FER foggy WIL sunny': 6.741262558061102e-06,
#  'FER foggy WIL cloudy': 6.741262558061102e-06,
#  'FER foggy WIL snowy': 6.741262558061102e-06,
#  'FER foggy WIL foggy': 6.741262558061102e-06,
#  'RED rainy MER rainy': 0.0021820816727912804,
#  'RED rainy MER sunny': 0.0021820816727912804,
#  'RED rainy MER cloudy': 0.0021820816727912804,
#  'RED rainy MER snowy': 0.0021820816727912804,
#  'RED rainy MER foggy': 0.0021820816727912804,
#  'RED rainy FER rainy': 0.0016313855390507862,
#  'RED rainy FER sunny': 0.0016313855390507862,
#  'RED rainy FER cloudy': 0.0016313855390507862,
#  'RED rainy FER snowy': 0.0016313855390507862,
#  'RED rainy FER foggy': 0.0016313855390507862,
#  'RED rainy RED rainy': 0.0010020185290616503,
#  'RED rainy RED sunny': 0.0010020185290616503,
#  'RED rainy RED cloudy': 0.0010020185290616503,
#  'RED rainy RED snowy': 0.0010020185290616503,
#  'RED rainy RED foggy': 0.0010020185290616503,
#  'RED rainy SCU rainy': 0.0004223383882821833,
#  'RED rainy SCU sunny': 0.0004223383882821833,
#  'RED rainy SCU cloudy': 0.0004223383882821833,
#  'RED rainy SCU snowy': 0.0004223383882821833,
#  'RED rainy SCU foggy': 0.0004223383882821833,
#  'RED rainy MCL rainy': 0.00036851094663837566,
#  'RED rainy MCL sunny': 0.00036851094663837566,
#  'RED rainy MCL cloudy': 0.00036851094663837566,
#  'RED rainy MCL snowy': 0.00036851094663837566,
#  'RED rainy MCL foggy': 0.00036851094663837566,
#  'RED rainy REN rainy': 0.00027741835308731647,
#  'RED rainy REN sunny': 0.00027741835308731647,
#  'RED rainy REN cloudy': 0.00027741835308731647,
#  'RED rainy REN snowy': 0.00027741835308731647,
#  'RED rainy REN foggy': 0.00027741835308731647,
#  'RED rainy ALF rainy': 0.0001449200351948668,
#  'RED rainy ALF sunny': 0.0001449200351948668,
#  'RED rainy ALF cloudy': 0.0001449200351948668,
#  'RED rainy ALF snowy': 0.0001449200351948668,
#  'RED rainy ALF foggy': 0.0001449200351948668,
#  'RED rainy RAC rainy': 0.00019046633197039638,
#  'RED rainy RAC sunny': 0.00019046633197039638,
#  'RED rainy RAC cloudy': 0.00019046633197039638,
#  'RED rainy RAC snowy': 0.00019046633197039638,
#  'RED rainy RAC foggy': 0.00019046633197039638,
#  'RED rainy HAA rainy': 0.00010765488328761534,
#  'RED rainy HAA sunny': 0.00010765488328761534,
#  'RED rainy HAA cloudy': 0.00010765488328761534,
#  'RED rainy HAA snowy': 0.00010765488328761534,
#  'RED rainy HAA foggy': 0.00010765488328761534,
#  'RED rainy WIL rainy': 4.140572434139053e-06,
#  'RED rainy WIL sunny': 4.140572434139053e-06,
#  'RED rainy WIL cloudy': 4.140572434139053e-06,
#  'RED rainy WIL snowy': 4.140572434139053e-06,
#  'RED rainy WIL foggy': 4.140572434139053e-06,
#  'RED sunny MER rainy': 0.0021820816727912804,
#  'RED sunny MER sunny': 0.0021820816727912804,
#  'RED sunny MER cloudy': 0.0021820816727912804,
#  'RED sunny MER snowy': 0.0021820816727912804,
#  'RED sunny MER foggy': 0.0021820816727912804,
#  'RED sunny FER rainy': 0.0016313855390507862,
#  'RED sunny FER sunny': 0.0016313855390507862,
#  'RED sunny FER cloudy': 0.0016313855390507862,
#  'RED sunny FER snowy': 0.0016313855390507862,
#  'RED sunny FER foggy': 0.0016313855390507862,
#  'RED sunny RED rainy': 0.0010020185290616503,
#  'RED sunny RED sunny': 0.0010020185290616503,
#  'RED sunny RED cloudy': 0.0010020185290616503,
#  'RED sunny RED snowy': 0.0010020185290616503,
#  'RED sunny RED foggy': 0.0010020185290616503,
#  'RED sunny SCU rainy': 0.0004223383882821833,
#  'RED sunny SCU sunny': 0.0004223383882821833,
#  'RED sunny SCU cloudy': 0.0004223383882821833,
#  'RED sunny SCU snowy': 0.0004223383882821833,
#  'RED sunny SCU foggy': 0.0004223383882821833,
#  'RED sunny MCL rainy': 0.00036851094663837566,
#  'RED sunny MCL sunny': 0.00036851094663837566,
#  'RED sunny MCL cloudy': 0.00036851094663837566,
#  'RED sunny MCL snowy': 0.00036851094663837566,
#  'RED sunny MCL foggy': 0.00036851094663837566,
#  'RED sunny REN rainy': 0.00027741835308731647,
#  'RED sunny REN sunny': 0.00027741835308731647,
#  'RED sunny REN cloudy': 0.00027741835308731647,
#  'RED sunny REN snowy': 0.00027741835308731647,
#  'RED sunny REN foggy': 0.00027741835308731647,
#  'RED sunny ALF rainy': 0.0001449200351948668,
#  'RED sunny ALF sunny': 0.0001449200351948668,
#  'RED sunny ALF cloudy': 0.0001449200351948668,
#  'RED sunny ALF snowy': 0.0001449200351948668,
#  'RED sunny ALF foggy': 0.0001449200351948668,
#  'RED sunny RAC rainy': 0.00019046633197039638,
#  'RED sunny RAC sunny': 0.00019046633197039638,
#  'RED sunny RAC cloudy': 0.00019046633197039638,
#  'RED sunny RAC snowy': 0.00019046633197039638,
#  'RED sunny RAC foggy': 0.00019046633197039638,
#  'RED sunny HAA rainy': 0.00010765488328761534,
#  'RED sunny HAA sunny': 0.00010765488328761534,
#  'RED sunny HAA cloudy': 0.00010765488328761534,
#  'RED sunny HAA snowy': 0.00010765488328761534,
#  'RED sunny HAA foggy': 0.00010765488328761534,
#  'RED sunny WIL rainy': 4.140572434139053e-06,
#  'RED sunny WIL sunny': 4.140572434139053e-06,
#  'RED sunny WIL cloudy': 4.140572434139053e-06,
#  'RED sunny WIL snowy': 4.140572434139053e-06,
#  'RED sunny WIL foggy': 4.140572434139053e-06,
#  'RED cloudy MER rainy': 0.0021820816727912804,
#  'RED cloudy MER sunny': 0.0021820816727912804,
#  'RED cloudy MER cloudy': 0.0021820816727912804,
#  'RED cloudy MER snowy': 0.0021820816727912804,
#  'RED cloudy MER foggy': 0.0021820816727912804,
#  'RED cloudy FER rainy': 0.0016313855390507862,
#  'RED cloudy FER sunny': 0.0016313855390507862,
#  'RED cloudy FER cloudy': 0.0016313855390507862,
#  'RED cloudy FER snowy': 0.0016313855390507862,
#  'RED cloudy FER foggy': 0.0016313855390507862,
#  'RED cloudy RED rainy': 0.0010020185290616503,
#  'RED cloudy RED sunny': 0.0010020185290616503,
#  'RED cloudy RED cloudy': 0.0010020185290616503,
#  'RED cloudy RED snowy': 0.0010020185290616503,
#  'RED cloudy RED foggy': 0.0010020185290616503,
#  'RED cloudy SCU rainy': 0.0004223383882821833,
#  'RED cloudy SCU sunny': 0.0004223383882821833,
#  'RED cloudy SCU cloudy': 0.0004223383882821833,
#  'RED cloudy SCU snowy': 0.0004223383882821833,
#  'RED cloudy SCU foggy': 0.0004223383882821833,
#  'RED cloudy MCL rainy': 0.00036851094663837566,
#  'RED cloudy MCL sunny': 0.00036851094663837566,
#  'RED cloudy MCL cloudy': 0.00036851094663837566,
#  'RED cloudy MCL snowy': 0.00036851094663837566,
#  'RED cloudy MCL foggy': 0.00036851094663837566,
#  'RED cloudy REN rainy': 0.00027741835308731647,
#  'RED cloudy REN sunny': 0.00027741835308731647,
#  'RED cloudy REN cloudy': 0.00027741835308731647,
#  'RED cloudy REN snowy': 0.00027741835308731647,
#  'RED cloudy REN foggy': 0.00027741835308731647,
#  'RED cloudy ALF rainy': 0.0001449200351948668,
#  'RED cloudy ALF sunny': 0.0001449200351948668,
#  'RED cloudy ALF cloudy': 0.0001449200351948668,
#  'RED cloudy ALF snowy': 0.0001449200351948668,
#  'RED cloudy ALF foggy': 0.0001449200351948668,
#  'RED cloudy RAC rainy': 0.00019046633197039638,
#  'RED cloudy RAC sunny': 0.00019046633197039638,
#  'RED cloudy RAC cloudy': 0.00019046633197039638,
#  'RED cloudy RAC snowy': 0.00019046633197039638,
#  'RED cloudy RAC foggy': 0.00019046633197039638,
#  'RED cloudy HAA rainy': 0.00010765488328761534,
#  'RED cloudy HAA sunny': 0.00010765488328761534,
#  'RED cloudy HAA cloudy': 0.00010765488328761534,
#  'RED cloudy HAA snowy': 0.00010765488328761534,
#  'RED cloudy HAA foggy': 0.00010765488328761534,
#  'RED cloudy WIL rainy': 4.140572434139053e-06,
#  'RED cloudy WIL sunny': 4.140572434139053e-06,
#  'RED cloudy WIL cloudy': 4.140572434139053e-06,
#  'RED cloudy WIL snowy': 4.140572434139053e-06,
#  'RED cloudy WIL foggy': 4.140572434139053e-06,
#  'RED snowy MER rainy': 0.0021820816727912804,
#  'RED snowy MER sunny': 0.0021820816727912804,
#  'RED snowy MER cloudy': 0.0021820816727912804,
#  'RED snowy MER snowy': 0.0021820816727912804,
#  'RED snowy MER foggy': 0.0021820816727912804,
#  'RED snowy FER rainy': 0.0016313855390507862,
#  'RED snowy FER sunny': 0.0016313855390507862,
#  'RED snowy FER cloudy': 0.0016313855390507862,
#  'RED snowy FER snowy': 0.0016313855390507862,
#  'RED snowy FER foggy': 0.0016313855390507862,
#  'RED snowy RED rainy': 0.0010020185290616503,
#  'RED snowy RED sunny': 0.0010020185290616503,
#  'RED snowy RED cloudy': 0.0010020185290616503,
#  'RED snowy RED snowy': 0.0010020185290616503,
#  'RED snowy RED foggy': 0.0010020185290616503,
#  'RED snowy SCU rainy': 0.0004223383882821833,
#  'RED snowy SCU sunny': 0.0004223383882821833,
#  'RED snowy SCU cloudy': 0.0004223383882821833,
#  'RED snowy SCU snowy': 0.0004223383882821833,
#  'RED snowy SCU foggy': 0.0004223383882821833,
#  'RED snowy MCL rainy': 0.00036851094663837566,
#  'RED snowy MCL sunny': 0.00036851094663837566,
#  'RED snowy MCL cloudy': 0.00036851094663837566,
#  'RED snowy MCL snowy': 0.00036851094663837566,
#  'RED snowy MCL foggy': 0.00036851094663837566,
#  'RED snowy REN rainy': 0.00027741835308731647,
#  'RED snowy REN sunny': 0.00027741835308731647,
#  'RED snowy REN cloudy': 0.00027741835308731647,
#  'RED snowy REN snowy': 0.00027741835308731647,
#  'RED snowy REN foggy': 0.00027741835308731647,
#  'RED snowy ALF rainy': 0.0001449200351948668,
#  'RED snowy ALF sunny': 0.0001449200351948668,
#  'RED snowy ALF cloudy': 0.0001449200351948668,
#  'RED snowy ALF snowy': 0.0001449200351948668,
#  'RED snowy ALF foggy': 0.0001449200351948668,
#  'RED snowy RAC rainy': 0.00019046633197039638,
#  'RED snowy RAC sunny': 0.00019046633197039638,
#  'RED snowy RAC cloudy': 0.00019046633197039638,
#  'RED snowy RAC snowy': 0.00019046633197039638,
#  'RED snowy RAC foggy': 0.00019046633197039638,
#  'RED snowy HAA rainy': 0.00010765488328761534,
#  'RED snowy HAA sunny': 0.00010765488328761534,
#  'RED snowy HAA cloudy': 0.00010765488328761534,
#  'RED snowy HAA snowy': 0.00010765488328761534,
#  'RED snowy HAA foggy': 0.00010765488328761534,
#  'RED snowy WIL rainy': 4.140572434139053e-06,
#  'RED snowy WIL sunny': 4.140572434139053e-06,
#  'RED snowy WIL cloudy': 4.140572434139053e-06,
#  'RED snowy WIL snowy': 4.140572434139053e-06,
#  'RED snowy WIL foggy': 4.140572434139053e-06,
#  'RED foggy MER rainy': 0.0021820816727912804,
#  'RED foggy MER sunny': 0.0021820816727912804,
#  'RED foggy MER cloudy': 0.0021820816727912804,
#  'RED foggy MER snowy': 0.0021820816727912804,
#  'RED foggy MER foggy': 0.0021820816727912804,
#  'RED foggy FER rainy': 0.0016313855390507862,
#  'RED foggy FER sunny': 0.0016313855390507862,
#  'RED foggy FER cloudy': 0.0016313855390507862,
#  'RED foggy FER snowy': 0.0016313855390507862,
#  'RED foggy FER foggy': 0.0016313855390507862,
#  'RED foggy RED rainy': 0.0010020185290616503,
#  'RED foggy RED sunny': 0.0010020185290616503,
#  'RED foggy RED cloudy': 0.0010020185290616503,
#  'RED foggy RED snowy': 0.0010020185290616503,
#  'RED foggy RED foggy': 0.0010020185290616503,
#  'RED foggy SCU rainy': 0.0004223383882821833,
#  'RED foggy SCU sunny': 0.0004223383882821833,
#  'RED foggy SCU cloudy': 0.0004223383882821833,
#  'RED foggy SCU snowy': 0.0004223383882821833,
#  'RED foggy SCU foggy': 0.0004223383882821833,
#  'RED foggy MCL rainy': 0.00036851094663837566,
#  'RED foggy MCL sunny': 0.00036851094663837566,
#  'RED foggy MCL cloudy': 0.00036851094663837566,
#  'RED foggy MCL snowy': 0.00036851094663837566,
#  'RED foggy MCL foggy': 0.00036851094663837566,
#  'RED foggy REN rainy': 0.00027741835308731647,
#  'RED foggy REN sunny': 0.00027741835308731647,
#  'RED foggy REN cloudy': 0.00027741835308731647,
#  'RED foggy REN snowy': 0.00027741835308731647,
#  'RED foggy REN foggy': 0.00027741835308731647,
#  'RED foggy ALF rainy': 0.0001449200351948668,
#  'RED foggy ALF sunny': 0.0001449200351948668,
#  'RED foggy ALF cloudy': 0.0001449200351948668,
#  'RED foggy ALF snowy': 0.0001449200351948668,
#  'RED foggy ALF foggy': 0.0001449200351948668,
#  'RED foggy RAC rainy': 0.00019046633197039638,
#  'RED foggy RAC sunny': 0.00019046633197039638,
#  'RED foggy RAC cloudy': 0.00019046633197039638,
#  'RED foggy RAC snowy': 0.00019046633197039638,
#  'RED foggy RAC foggy': 0.00019046633197039638,
#  'RED foggy HAA rainy': 0.00010765488328761534,
#  'RED foggy HAA sunny': 0.00010765488328761534,
#  'RED foggy HAA cloudy': 0.00010765488328761534,
#  'RED foggy HAA snowy': 0.00010765488328761534,
#  'RED foggy HAA foggy': 0.00010765488328761534,
#  'RED foggy WIL rainy': 4.140572434139053e-06,
#  'RED foggy WIL sunny': 4.140572434139053e-06,
#  'RED foggy WIL cloudy': 4.140572434139053e-06,
#  'RED foggy WIL snowy': 4.140572434139053e-06,
#  'RED foggy WIL foggy': 4.140572434139053e-06,
#  'SCU rainy MER rainy': 0.0009197203744822751,
#  'SCU rainy MER sunny': 0.0009197203744822751,
#  'SCU rainy MER cloudy': 0.0009197203744822751,
#  'SCU rainy MER snowy': 0.0009197203744822751,
#  'SCU rainy MER foggy': 0.0009197203744822751,
#  'SCU rainy FER rainy': 0.0006876087809222322,
#  'SCU rainy FER sunny': 0.0006876087809222322,
#  'SCU rainy FER cloudy': 0.0006876087809222322,
#  'SCU rainy FER snowy': 0.0006876087809222322,
#  'SCU rainy FER foggy': 0.0006876087809222322,
#  'SCU rainy RED rainy': 0.0004223383882821833,
#  'SCU rainy RED sunny': 0.0004223383882821833,
#  'SCU rainy RED cloudy': 0.0004223383882821833,
#  'SCU rainy RED snowy': 0.0004223383882821833,
#  'SCU rainy RED foggy': 0.0004223383882821833,
#  'SCU rainy SCU rainy': 0.0001780103950610855,
#  'SCU rainy SCU sunny': 0.0001780103950610855,
#  'SCU rainy SCU cloudy': 0.0001780103950610855,
#  'SCU rainy SCU snowy': 0.0001780103950610855,
#  'SCU rainy SCU foggy': 0.0001780103950610855,
#  'SCU rainy MCL rainy': 0.00015532279569055503,
#  'SCU rainy MCL sunny': 0.00015532279569055503,
#  'SCU rainy MCL cloudy': 0.00015532279569055503,
#  'SCU rainy MCL snowy': 0.00015532279569055503,
#  'SCU rainy MCL foggy': 0.00015532279569055503,
#  'SCU rainy REN rainy': 0.0001169283967558111,
#  'SCU rainy REN sunny': 0.0001169283967558111,
#  'SCU rainy REN cloudy': 0.0001169283967558111,
#  'SCU rainy REN snowy': 0.0001169283967558111,
#  'SCU rainy REN foggy': 0.0001169283967558111,
#  'SCU rainy ALF rainy': 6.108199830527446e-05,
#  'SCU rainy ALF sunny': 6.108199830527446e-05,
#  'SCU rainy ALF cloudy': 6.108199830527446e-05,
#  'SCU rainy ALF snowy': 6.108199830527446e-05,
#  'SCU rainy ALF foggy': 6.108199830527446e-05,
#  'SCU rainy RAC rainy': 8.027919777264641e-05,
#  'SCU rainy RAC sunny': 8.027919777264641e-05,
#  'SCU rainy RAC cloudy': 8.027919777264641e-05,
#  'SCU rainy RAC snowy': 8.027919777264641e-05,
#  'SCU rainy RAC foggy': 8.027919777264641e-05,
#  'SCU rainy HAA rainy': 4.5375198741061014e-05,
#  'SCU rainy HAA sunny': 4.5375198741061014e-05,
#  'SCU rainy HAA cloudy': 4.5375198741061014e-05,
#  'SCU rainy HAA snowy': 4.5375198741061014e-05,
#  'SCU rainy HAA foggy': 4.5375198741061014e-05,
#  'SCU rainy WIL rainy': 1.7451999515792701e-06,
#  'SCU rainy WIL sunny': 1.7451999515792701e-06,
#  'SCU rainy WIL cloudy': 1.7451999515792701e-06,
#  'SCU rainy WIL snowy': 1.7451999515792701e-06,
#  'SCU rainy WIL foggy': 1.7451999515792701e-06,
#  'SCU sunny MER rainy': 0.0009197203744822751,
#  'SCU sunny MER sunny': 0.0009197203744822751,
#  'SCU sunny MER cloudy': 0.0009197203744822751,
#  'SCU sunny MER snowy': 0.0009197203744822751,
#  'SCU sunny MER foggy': 0.0009197203744822751,
#  'SCU sunny FER rainy': 0.0006876087809222322,
#  'SCU sunny FER sunny': 0.0006876087809222322,
#  'SCU sunny FER cloudy': 0.0006876087809222322,
#  'SCU sunny FER snowy': 0.0006876087809222322,
#  'SCU sunny FER foggy': 0.0006876087809222322,
#  'SCU sunny RED rainy': 0.0004223383882821833,
#  'SCU sunny RED sunny': 0.0004223383882821833,
#  'SCU sunny RED cloudy': 0.0004223383882821833,
#  'SCU sunny RED snowy': 0.0004223383882821833,
#  'SCU sunny RED foggy': 0.0004223383882821833,
#  'SCU sunny SCU rainy': 0.0001780103950610855,
#  'SCU sunny SCU sunny': 0.0001780103950610855,
#  'SCU sunny SCU cloudy': 0.0001780103950610855,
#  'SCU sunny SCU snowy': 0.0001780103950610855,
#  'SCU sunny SCU foggy': 0.0001780103950610855,
#  'SCU sunny MCL rainy': 0.00015532279569055503,
#  'SCU sunny MCL sunny': 0.00015532279569055503,
#  'SCU sunny MCL cloudy': 0.00015532279569055503,
#  'SCU sunny MCL snowy': 0.00015532279569055503,
#  'SCU sunny MCL foggy': 0.00015532279569055503,
#  'SCU sunny REN rainy': 0.0001169283967558111,
#  'SCU sunny REN sunny': 0.0001169283967558111,
#  'SCU sunny REN cloudy': 0.0001169283967558111,
#  'SCU sunny REN snowy': 0.0001169283967558111,
#  'SCU sunny REN foggy': 0.0001169283967558111,
#  'SCU sunny ALF rainy': 6.108199830527446e-05,
#  'SCU sunny ALF sunny': 6.108199830527446e-05,
#  'SCU sunny ALF cloudy': 6.108199830527446e-05,
#  'SCU sunny ALF snowy': 6.108199830527446e-05,
#  'SCU sunny ALF foggy': 6.108199830527446e-05,
#  'SCU sunny RAC rainy': 8.027919777264641e-05,
#  'SCU sunny RAC sunny': 8.027919777264641e-05,
#  'SCU sunny RAC cloudy': 8.027919777264641e-05,
#  'SCU sunny RAC snowy': 8.027919777264641e-05,
#  'SCU sunny RAC foggy': 8.027919777264641e-05,
#  'SCU sunny HAA rainy': 4.5375198741061014e-05,
#  'SCU sunny HAA sunny': 4.5375198741061014e-05,
#  'SCU sunny HAA cloudy': 4.5375198741061014e-05,
#  'SCU sunny HAA snowy': 4.5375198741061014e-05,
#  'SCU sunny HAA foggy': 4.5375198741061014e-05,
#  'SCU sunny WIL rainy': 1.7451999515792701e-06,
#  'SCU sunny WIL sunny': 1.7451999515792701e-06,
#  'SCU sunny WIL cloudy': 1.7451999515792701e-06,
#  'SCU sunny WIL snowy': 1.7451999515792701e-06,
#  'SCU sunny WIL foggy': 1.7451999515792701e-06,
#  'SCU cloudy MER rainy': 0.0009197203744822751,
#  'SCU cloudy MER sunny': 0.0009197203744822751,
#  'SCU cloudy MER cloudy': 0.0009197203744822751,
#  'SCU cloudy MER snowy': 0.0009197203744822751,
#  'SCU cloudy MER foggy': 0.0009197203744822751,
#  'SCU cloudy FER rainy': 0.0006876087809222322,
#  'SCU cloudy FER sunny': 0.0006876087809222322,
#  'SCU cloudy FER cloudy': 0.0006876087809222322,
#  'SCU cloudy FER snowy': 0.0006876087809222322,
#  'SCU cloudy FER foggy': 0.0006876087809222322,
#  'SCU cloudy RED rainy': 0.0004223383882821833,
#  'SCU cloudy RED sunny': 0.0004223383882821833,
#  'SCU cloudy RED cloudy': 0.0004223383882821833,
#  'SCU cloudy RED snowy': 0.0004223383882821833,
#  'SCU cloudy RED foggy': 0.0004223383882821833,
#  'SCU cloudy SCU rainy': 0.0001780103950610855,
#  'SCU cloudy SCU sunny': 0.0001780103950610855,
#  'SCU cloudy SCU cloudy': 0.0001780103950610855,
#  'SCU cloudy SCU snowy': 0.0001780103950610855,
#  'SCU cloudy SCU foggy': 0.0001780103950610855,
#  'SCU cloudy MCL rainy': 0.00015532279569055503,
#  'SCU cloudy MCL sunny': 0.00015532279569055503,
#  'SCU cloudy MCL cloudy': 0.00015532279569055503,
#  'SCU cloudy MCL snowy': 0.00015532279569055503,
#  'SCU cloudy MCL foggy': 0.00015532279569055503,
#  'SCU cloudy REN rainy': 0.0001169283967558111,
#  'SCU cloudy REN sunny': 0.0001169283967558111,
#  'SCU cloudy REN cloudy': 0.0001169283967558111,
#  'SCU cloudy REN snowy': 0.0001169283967558111,
#  'SCU cloudy REN foggy': 0.0001169283967558111,
#  'SCU cloudy ALF rainy': 6.108199830527446e-05,
#  'SCU cloudy ALF sunny': 6.108199830527446e-05,
#  'SCU cloudy ALF cloudy': 6.108199830527446e-05,
#  'SCU cloudy ALF snowy': 6.108199830527446e-05,
#  'SCU cloudy ALF foggy': 6.108199830527446e-05,
#  'SCU cloudy RAC rainy': 8.027919777264641e-05,
#  'SCU cloudy RAC sunny': 8.027919777264641e-05,
#  'SCU cloudy RAC cloudy': 8.027919777264641e-05,
#  'SCU cloudy RAC snowy': 8.027919777264641e-05,
#  'SCU cloudy RAC foggy': 8.027919777264641e-05,
#  'SCU cloudy HAA rainy': 4.5375198741061014e-05,
#  'SCU cloudy HAA sunny': 4.5375198741061014e-05,
#  'SCU cloudy HAA cloudy': 4.5375198741061014e-05,
#  'SCU cloudy HAA snowy': 4.5375198741061014e-05,
#  'SCU cloudy HAA foggy': 4.5375198741061014e-05,
#  'SCU cloudy WIL rainy': 1.7451999515792701e-06,
#  'SCU cloudy WIL sunny': 1.7451999515792701e-06,
#  'SCU cloudy WIL cloudy': 1.7451999515792701e-06,
#  'SCU cloudy WIL snowy': 1.7451999515792701e-06,
#  'SCU cloudy WIL foggy': 1.7451999515792701e-06,
#  'SCU snowy MER rainy': 0.0009197203744822751,
#  'SCU snowy MER sunny': 0.0009197203744822751,
#  'SCU snowy MER cloudy': 0.0009197203744822751,
#  'SCU snowy MER snowy': 0.0009197203744822751,
#  'SCU snowy MER foggy': 0.0009197203744822751,
#  'SCU snowy FER rainy': 0.0006876087809222322,
#  'SCU snowy FER sunny': 0.0006876087809222322,
#  'SCU snowy FER cloudy': 0.0006876087809222322,
#  'SCU snowy FER snowy': 0.0006876087809222322,
#  'SCU snowy FER foggy': 0.0006876087809222322,
#  'SCU snowy RED rainy': 0.0004223383882821833,
#  'SCU snowy RED sunny': 0.0004223383882821833,
#  'SCU snowy RED cloudy': 0.0004223383882821833,
#  'SCU snowy RED snowy': 0.0004223383882821833,
#  'SCU snowy RED foggy': 0.0004223383882821833,
#  'SCU snowy SCU rainy': 0.0001780103950610855,
#  'SCU snowy SCU sunny': 0.0001780103950610855,
#  'SCU snowy SCU cloudy': 0.0001780103950610855,
#  'SCU snowy SCU snowy': 0.0001780103950610855,
#  'SCU snowy SCU foggy': 0.0001780103950610855,
#  'SCU snowy MCL rainy': 0.00015532279569055503,
#  'SCU snowy MCL sunny': 0.00015532279569055503,
#  'SCU snowy MCL cloudy': 0.00015532279569055503,
#  'SCU snowy MCL snowy': 0.00015532279569055503,
#  'SCU snowy MCL foggy': 0.00015532279569055503,
#  'SCU snowy REN rainy': 0.0001169283967558111,
#  'SCU snowy REN sunny': 0.0001169283967558111,
#  'SCU snowy REN cloudy': 0.0001169283967558111,
#  'SCU snowy REN snowy': 0.0001169283967558111,
#  'SCU snowy REN foggy': 0.0001169283967558111,
#  'SCU snowy ALF rainy': 6.108199830527446e-05,
#  'SCU snowy ALF sunny': 6.108199830527446e-05,
#  'SCU snowy ALF cloudy': 6.108199830527446e-05,
#  'SCU snowy ALF snowy': 6.108199830527446e-05,
#  'SCU snowy ALF foggy': 6.108199830527446e-05,
#  'SCU snowy RAC rainy': 8.027919777264641e-05,
#  'SCU snowy RAC sunny': 8.027919777264641e-05,
#  'SCU snowy RAC cloudy': 8.027919777264641e-05,
#  'SCU snowy RAC snowy': 8.027919777264641e-05,
#  'SCU snowy RAC foggy': 8.027919777264641e-05,
#  'SCU snowy HAA rainy': 4.5375198741061014e-05,
#  'SCU snowy HAA sunny': 4.5375198741061014e-05,
#  'SCU snowy HAA cloudy': 4.5375198741061014e-05,
#  'SCU snowy HAA snowy': 4.5375198741061014e-05,
#  'SCU snowy HAA foggy': 4.5375198741061014e-05,
#  'SCU snowy WIL rainy': 1.7451999515792701e-06,
#  'SCU snowy WIL sunny': 1.7451999515792701e-06,
#  'SCU snowy WIL cloudy': 1.7451999515792701e-06,
#  'SCU snowy WIL snowy': 1.7451999515792701e-06,
#  'SCU snowy WIL foggy': 1.7451999515792701e-06,
#  'SCU foggy MER rainy': 0.0009197203744822751,
#  'SCU foggy MER sunny': 0.0009197203744822751,
#  'SCU foggy MER cloudy': 0.0009197203744822751,
#  'SCU foggy MER snowy': 0.0009197203744822751,
#  'SCU foggy MER foggy': 0.0009197203744822751,
#  'SCU foggy FER rainy': 0.0006876087809222322,
#  'SCU foggy FER sunny': 0.0006876087809222322,
#  'SCU foggy FER cloudy': 0.0006876087809222322,
#  'SCU foggy FER snowy': 0.0006876087809222322,
#  'SCU foggy FER foggy': 0.0006876087809222322,
#  'SCU foggy RED rainy': 0.0004223383882821833,
#  'SCU foggy RED sunny': 0.0004223383882821833,
#  'SCU foggy RED cloudy': 0.0004223383882821833,
#  'SCU foggy RED snowy': 0.0004223383882821833,
#  'SCU foggy RED foggy': 0.0004223383882821833,
#  'SCU foggy SCU rainy': 0.0001780103950610855,
#  'SCU foggy SCU sunny': 0.0001780103950610855,
#  'SCU foggy SCU cloudy': 0.0001780103950610855,
#  'SCU foggy SCU snowy': 0.0001780103950610855,
#  'SCU foggy SCU foggy': 0.0001780103950610855,
#  'SCU foggy MCL rainy': 0.00015532279569055503,
#  'SCU foggy MCL sunny': 0.00015532279569055503,
#  'SCU foggy MCL cloudy': 0.00015532279569055503,
#  'SCU foggy MCL snowy': 0.00015532279569055503,
#  'SCU foggy MCL foggy': 0.00015532279569055503,
#  'SCU foggy REN rainy': 0.0001169283967558111,
#  'SCU foggy REN sunny': 0.0001169283967558111,
#  'SCU foggy REN cloudy': 0.0001169283967558111,
#  'SCU foggy REN snowy': 0.0001169283967558111,
#  'SCU foggy REN foggy': 0.0001169283967558111,
#  'SCU foggy ALF rainy': 6.108199830527446e-05,
#  'SCU foggy ALF sunny': 6.108199830527446e-05,
#  'SCU foggy ALF cloudy': 6.108199830527446e-05,
#  'SCU foggy ALF snowy': 6.108199830527446e-05,
#  'SCU foggy ALF foggy': 6.108199830527446e-05,
#  'SCU foggy RAC rainy': 8.027919777264641e-05,
#  'SCU foggy RAC sunny': 8.027919777264641e-05,
#  'SCU foggy RAC cloudy': 8.027919777264641e-05,
#  'SCU foggy RAC snowy': 8.027919777264641e-05,
#  'SCU foggy RAC foggy': 8.027919777264641e-05,
#  'SCU foggy HAA rainy': 4.5375198741061014e-05,
#  'SCU foggy HAA sunny': 4.5375198741061014e-05,
#  'SCU foggy HAA cloudy': 4.5375198741061014e-05,
#  'SCU foggy HAA snowy': 4.5375198741061014e-05,
#  'SCU foggy HAA foggy': 4.5375198741061014e-05,
#  'SCU foggy WIL rainy': 1.7451999515792701e-06,
#  'SCU foggy WIL sunny': 1.7451999515792701e-06,
#  'SCU foggy WIL cloudy': 1.7451999515792701e-06,
#  'SCU foggy WIL snowy': 1.7451999515792701e-06,
#  'SCU foggy WIL foggy': 1.7451999515792701e-06,
#  ...}

# %%
def Mer_first_win_rain(outcome):  return outcome[0:9] == 'MER rainy' 
def both_win(outcome): return outcome[0:3] == 'MER' and outcome[10:13] == 'MER'

# %%
# def Mer_second_win_rain(outcome):  return outcome[0:9] != 'MER rainy' and outcome[10:] == 'MER rainy'
# def both_win(outcome): return outcome[0:3] == 'MER' and outcome[10:13] == 'MER'

# %%
def Mer_win_rain(outcome):  return  'MER rainy' in outcome

# %%
# both_win_in_Rain_1 = p(both_win, such_that(Mer_first_win_rain,Game_weather_all))
# both_win_in_Rain = both_win_in_Rain_1 + both_win_in_Rain_2

# %%
such_that(Mer_win_rain,Game_weather_all)
# Out:
# {'MER rainy MER rainy': 0.03569735148682514,
#  'MER rainy MER sunny': 0.03569735148682514,
#  'MER rainy MER cloudy': 0.03569735148682514,
#  'MER rainy MER snowy': 0.03569735148682514,
#  'MER rainy MER foggy': 0.03569735148682514,
#  'MER rainy FER rainy': 0.026688342477816138,
#  'MER rainy FER sunny': 0.026688342477816138,
#  'MER rainy FER cloudy': 0.026688342477816138,
#  'MER rainy FER snowy': 0.026688342477816138,
#  'MER rainy FER foggy': 0.026688342477816138,
#  'MER rainy RED rainy': 0.016392332181805854,
#  'MER rainy RED sunny': 0.016392332181805854,
#  'MER rainy RED cloudy': 0.016392332181805854,
#  'MER rainy RED snowy': 0.016392332181805854,
#  'MER rainy RED foggy': 0.016392332181805854,
#  'MER rainy SCU rainy': 0.00690916480390164,
#  'MER rainy SCU sunny': 0.00690916480390164,
#  'MER rainy SCU cloudy': 0.00690916480390164,
#  'MER rainy SCU snowy': 0.00690916480390164,
#  'MER rainy SCU foggy': 0.00690916480390164,
#  'MER rainy MCL rainy': 0.006028584975953394,
#  'MER rainy MCL sunny': 0.006028584975953394,
#  'MER rainy MCL cloudy': 0.006028584975953394,
#  'MER rainy MCL snowy': 0.006028584975953394,
#  'MER rainy MCL foggy': 0.006028584975953394,
#  'MER rainy REN rainy': 0.004538372959425588,
#  'MER rainy REN sunny': 0.004538372959425588,
#  'MER rainy REN cloudy': 0.004538372959425588,
#  'MER rainy REN snowy': 0.004538372959425588,
#  'MER rainy REN foggy': 0.004538372959425588,
#  'MER rainy ALF rainy': 0.0023707918444760535,
#  'MER rainy ALF sunny': 0.0023707918444760535,
#  'MER rainy ALF cloudy': 0.0023707918444760535,
#  'MER rainy ALF snowy': 0.0023707918444760535,
#  'MER rainy ALF foggy': 0.0023707918444760535,
#  'MER rainy RAC rainy': 0.0031158978527399558,
#  'MER rainy RAC sunny': 0.0031158978527399558,
#  'MER rainy RAC cloudy': 0.0031158978527399558,
#  'MER rainy RAC snowy': 0.0031158978527399558,
#  'MER rainy RAC foggy': 0.0031158978527399558,
#  'MER rainy HAA rainy': 0.0017611596558964966,
#  'MER rainy HAA sunny': 0.0017611596558964966,
#  'MER rainy HAA cloudy': 0.0017611596558964966,
#  'MER rainy HAA snowy': 0.0017611596558964966,
#  'MER rainy HAA foggy': 0.0017611596558964966,
#  'MER rainy WIL rainy': 6.773690984217296e-05,
#  'MER rainy WIL sunny': 6.773690984217296e-05,
#  'MER rainy WIL cloudy': 6.773690984217296e-05,
#  'MER rainy WIL snowy': 6.773690984217296e-05,
#  'MER rainy WIL foggy': 6.773690984217296e-05,
#  'MER sunny MER rainy': 0.03569735148682514,
#  'MER cloudy MER rainy': 0.03569735148682514,
#  'MER snowy MER rainy': 0.03569735148682514,
#  'MER foggy MER rainy': 0.03569735148682514,
#  'FER rainy MER rainy': 0.026688342477816138,
#  'FER sunny MER rainy': 0.026688342477816138,
#  'FER cloudy MER rainy': 0.026688342477816138,
#  'FER snowy MER rainy': 0.026688342477816138,
#  'FER foggy MER rainy': 0.026688342477816138,
#  'RED rainy MER rainy': 0.016392332181805854,
#  'RED sunny MER rainy': 0.016392332181805854,
#  'RED cloudy MER rainy': 0.016392332181805854,
#  'RED snowy MER rainy': 0.016392332181805854,
#  'RED foggy MER rainy': 0.016392332181805854,
#  'SCU rainy MER rainy': 0.00690916480390164,
#  'SCU sunny MER rainy': 0.00690916480390164,
#  'SCU cloudy MER rainy': 0.00690916480390164,
#  'SCU snowy MER rainy': 0.00690916480390164,
#  'SCU foggy MER rainy': 0.00690916480390164,
#  'MCL rainy MER rainy': 0.006028584975953394,
#  'MCL sunny MER rainy': 0.006028584975953394,
#  'MCL cloudy MER rainy': 0.006028584975953394,
#  'MCL snowy MER rainy': 0.006028584975953394,
#  'MCL foggy MER rainy': 0.006028584975953394,
#  'REN rainy MER rainy': 0.004538372959425588,
#  'REN sunny MER rainy': 0.004538372959425588,
#  'REN cloudy MER rainy': 0.004538372959425588,
#  'REN snowy MER rainy': 0.004538372959425588,
#  'REN foggy MER rainy': 0.004538372959425588,
#  'ALF rainy MER rainy': 0.0023707918444760535,
#  'ALF sunny MER rainy': 0.0023707918444760535,
#  'ALF cloudy MER rainy': 0.0023707918444760535,
#  'ALF snowy MER rainy': 0.0023707918444760535,
#  'ALF foggy MER rainy': 0.0023707918444760535,
#  'RAC rainy MER rainy': 0.0031158978527399558,
#  'RAC sunny MER rainy': 0.0031158978527399558,
#  'RAC cloudy MER rainy': 0.0031158978527399558,
#  'RAC snowy MER rainy': 0.0031158978527399558,
#  'RAC foggy MER rainy': 0.0031158978527399558,
#  'HAA rainy MER rainy': 0.0017611596558964966,
#  'HAA sunny MER rainy': 0.0017611596558964966,
#  'HAA cloudy MER rainy': 0.0017611596558964966,
#  'HAA snowy MER rainy': 0.0017611596558964966,
#  'HAA foggy MER rainy': 0.0017611596558964966,
#  'WIL rainy MER rainy': 6.773690984217296e-05,
#  'WIL sunny MER rainy': 6.773690984217296e-05,
#  'WIL cloudy MER rainy': 6.773690984217296e-05,
#  'WIL snowy MER rainy': 6.773690984217296e-05,
#  'WIL foggy MER rainy': 6.773690984217296e-05}

# %% [markdown]
# #### Mercedes wins one of these two races on a rainy day. What is the probability Mercedes wins both races, assuming races can be held on either rainy, sunny, cloudy, snowy or foggy days?

# %%
p(both_win,such_that(Mer_win_rain,Game_weather_all))
# Out:
# 0.28557881189460105
